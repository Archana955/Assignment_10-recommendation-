# %% [markdown]
# # **Build a recommender system by using cosine simillarties score.**

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Import the  book dataset**

# %%
from google.colab import files
uploaded=files.upload()

# %%
book = pd.read_csv("book_1.csv", encoding='latin-1')

# %%
book

# %% [markdown]
# # EDA

# %%
book.shape

# %%
book.isnull().sum()

# %%
book.drop(book.columns[[0]],axis=1,inplace =True)
book

# %%
#Renaming the colums
book.columns = ["UserID","BookTitle","BookRating"]

# %%
book[0:5]

# %%
# number of unique users in the dataset
len(book.UserID.unique())

# %%
book_df=book.pivot_table(index='UserID',
                     columns='BookTitle',
                     values='BookRating').reset_index(drop=True)

# %%
book_df

# %%
book_df.fillna(0,inplace=True)

# %%
book_df

# %%
#AVERAGE RATING OF BOOKS
AVG = book['BookRating'].mean()
print(AVG)

# %% [markdown]
# # **Calculating Cosine Similarity between Users**

# %%
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import cosine,correlation

# %%
user_sim=1-pairwise_distances(book_df.values,metric='cosine')

# %%
user_sim

# %%
#store  the result in DataFrame
user_sim_df=pd.DataFrame(user_sim)

# %%
user_sim_df

# %%
#Set the index and column names to user ids 
user_sim_df.index = book.UserID.unique()
user_sim_df.columns = book.UserID.unique()

# %%
user_sim_df.iloc[0:10,0:10]

# %%
np.fill_diagonal(user_sim,0)
user_sim_df

# %%
#Most Similar Users
user_sim_df.idxmax(axis=1)[0:10]

# %%
book[(book['UserID']==276748 ) | (book['UserID']==161677) ]

# %%
user_1=book[(book['UserID']==276748)]

# %%
user_1.book

# %%
user_2=book[(book['UserID']==161677)]

# %%
user_2.BookTitle

# %%
pd.merge(user_1,user_2,on='BookTitle',how='outer')
